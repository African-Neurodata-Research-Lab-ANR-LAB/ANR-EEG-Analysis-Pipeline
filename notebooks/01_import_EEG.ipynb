# %% [markdown]
# # ANR EEG Analysis Pipeline
# ## Notebook 01: EEG Data Import
#
# African NeuroData Research Lab (ANR)
#
# Goal:
# - Load EEG recordings
# - Inspect channels
# - Prepare data for analysis
#
# Supported roadmap:
# - Muse CSV
# - EDF
# - FIF
# - BIDS EEG

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Replace with your EEG CSV path
file_path = "../data/example/eeg_recording.csv"

# Load EEG data
# eeg = pd.read_csv(file_path)

print("ANR EEG import module ready")

# %% [markdown]
# ## Expected Muse channels
#
# Typical Muse EEG channels:
#
# - TP9
# - AF7
# - AF8
# - TP10
#
# The next steps will convert data into MNE format.

# %%
# Example channel inspection

# print(eeg.head())
# print(eeg.columns)

print("Channel inspection placeholder")
